# %%
import pandas as pd
import numpy as np
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Raw data entry

data = {
    "EmpId": [101, 102, "103", 104, 105, 106, 107, 108, 109, 110],
    "fullName": [
        "  Alice Johnson  ", "MICHEAL smith", "sarah lee", "David-Kim", None, "john brown",
        "Emma Wilson", "TOM  davis", "Jane Miller", "Chris taylor"
    ], 
     "Dept": ["IT", "hr", "Mktng", "IT", "Customer Care", "marketing", "Finance", None, "HR", "marketing"],
    "Age": [29, "thirty-five", 26, 31, 42, 27, 33, 30, None, 28],
    "Salary($)": ["$5500.50", "4800", "4200.75", "NaN", "6100", "4,300", "5800", "5000", "4700.0", "4400"],
    "JoinDate" : [ 
        "12-04-2021" , "2020.11.01" , "Jan 18, 2022" , "2019/9/25" , "07/05/18" , "2021-10-14" , 
        "2019/12/01" , "2020-03-22" , "May 10th, 2021" , "2022-02-05" 
    ],
    "Performance": [87, "73", 90, 65, 82, 75, 88, None, "79%", "91"],
    "Remote?": ["Yes", "No", "Y", "N", "yes", "no", "Y", "Yes", None, "True"]
}

# %%
data_frame = pd.DataFrame(data)

data_frame
# Out:
#   EmpId           fullName           Dept          Age Salary($)  \
# 0   101    Alice Johnson               IT           29  $5500.50
# 1   102      MICHEAL smith             hr  thirty-five      4800
# 2   103          sarah lee          Mktng           26   4200.75
# 3   104          David-Kim             IT           31       NaN
# 4   105                NaN  Customer Care           42      6100
# 5   106         john brown      marketing           27     4,300
# 6   107        Emma Wilson        Finance           33      5800
# 7   108         TOM  davis            NaN           30      5000
# 8   109        Jane Miller             HR         None    4700.0
# 9   110       Chris taylor      marketing           28      4400
#
#          JoinDate Performance Remote?
# 0      12-04-2021          87     Yes
# 1      2020.11.01          73      No
# 2    Jan 18, 2022          90       Y
# 3       2019/9/25          65       N
# 4        07/05/18          82     yes
# ...

# %%
#Converting the DataFrame object to csv file using "to_csv"
data_frame.to_csv("data/employee_dataset.csv", index=False)

#Loading the csv file
df = pd.read_csv("data/employee_dataset.csv")

df
# Out:
#    EmpId           fullName           Dept          Age Salary($)  \
# 0    101    Alice Johnson               IT           29  $5500.50
# 1    102      MICHEAL smith             hr  thirty-five      4800
# 2    103          sarah lee          Mktng           26   4200.75
# 3    104          David-Kim             IT           31       NaN
# 4    105                NaN  Customer Care           42      6100
# 5    106         john brown      marketing           27     4,300
# 6    107        Emma Wilson        Finance           33      5800
# 7    108         TOM  davis            NaN           30      5000
# 8    109        Jane Miller             HR          NaN    4700.0
# 9    110       Chris taylor      marketing           28      4400
#
#          JoinDate Performance Remote?
# 0      12-04-2021          87     Yes
# 1      2020.11.01          73      No
# 2    Jan 18, 2022          90       Y
# 3       2019/9/25          65       N
# 4        07/05/18          82     yes
# ...

# %%
#Exploring dataset using "pd.info()" 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpId        10 non-null     int64
#  1   fullName     9 non-null      str
#  2   Dept         9 non-null      str
#  3   Age          9 non-null      str
#  4   Salary($)    9 non-null      str
#  5   JoinDate     10 non-null     str
#  6   Performance  9 non-null      str
#  7   Remote?      9 non-null      str
# dtypes: int64(1), str(7)
# memory usage: 772.0 bytes

# %%
#Knowing the shape (row,column) of the data using ".shape"
df.shape
# Out:
# (10, 8)

# %%
#Displaying the first five data using ".head"
df.head()
# Out:
#    EmpId           fullName           Dept          Age Salary($)  \
# 0    101    Alice Johnson               IT           29  $5500.50
# 1    102      MICHEAL smith             hr  thirty-five      4800
# 2    103          sarah lee          Mktng           26   4200.75
# 3    104          David-Kim             IT           31       NaN
# 4    105                NaN  Customer Care           42      6100
#
#        JoinDate Performance Remote?
# 0    12-04-2021          87     Yes
# 1    2020.11.01          73      No
# 2  Jan 18, 2022          90       Y
# 3     2019/9/25          65       N
# 4      07/05/18          82     yes

# %%
#Display columns
df.columns
# Out:
# Index(['EmpId', 'fullName', 'Dept', 'Age', 'Salary($)', 'JoinDate',
#        'Performance', 'Remote?'],
#       dtype='str')

# %%
#Check for Null
df.isnull().sum()
# Out:
# EmpId          0
# fullName       1
# Dept           1
# Age            1
# Salary($)      1
# JoinDate       0
# Performance    1
# Remote?        1
# dtype: int64

# %%
#Inspect Unique values using ".unique"
print(df['Dept'].unique())
print(df['Age'].unique())
print(df['Remote?'].unique())
# Out:
# <StringArray>
# ['IT', 'hr', 'Mktng', 'Customer Care', 'marketing', 'Finance', nan, 'HR']
# Length: 8, dtype: str
# <StringArray>
# ['29', 'thirty-five', '26', '31', '42', '27', '33', '30', nan, '28']
# Length: 10, dtype: str
# <StringArray>
# ['Yes', 'No', 'Y', 'N', 'yes', 'no', nan, 'True']
# Length: 8, dtype: str

# %%
#Access values in a column
df['Salary($)']
# Out:
# 0    $5500.50
# 1        4800
# 2     4200.75
# 3         NaN
# 4        6100
# 5       4,300
# 6        5800
# 7        5000
# 8      4700.0
# 9        4400
# Name: Salary($), dtype: str

# %%
#Revealing all characters in a column value using '.to_list'
df['fullName'].to_list()
# Out:
# ['  Alice Johnson  ',
#  'MICHEAL smith',
#  'sarah lee',
#  'David-Kim',
#  nan,
#  'john brown',
#  'Emma Wilson',
#  'TOM  davis',
#  'Jane Miller',
#  'Chris taylor']

# %%
#7th May, 2026
#Data Cleaning
#Renaming using ".rename" and ",inplace=True"
df.rename(columns={
    "EmpId": "emp_id",
    "fullName": "full_name",
    "Dept": "department",
    "Age": "age",
    "Salary($)": "salary",
    "JoinDate": "join_date",
    "Performance": "performance",
    "Remote?": "remote"
},inplace=True)

df
# Out:
#    emp_id          full_name     department          age    salary  \
# 0     101    Alice Johnson               IT           29  $5500.50
# 1     102      MICHEAL smith             hr  thirty-five      4800
# 2     103          sarah lee          Mktng           26   4200.75
# 3     104          David-Kim             IT           31       NaN
# 4     105                NaN  Customer Care           42      6100
# 5     106         john brown      marketing           27     4,300
# 6     107        Emma Wilson        Finance           33      5800
# 7     108         TOM  davis            NaN           30      5000
# 8     109        Jane Miller             HR          NaN    4700.0
# 9     110       Chris taylor      marketing           28      4400
#
#         join_date performance remote
# 0      12-04-2021          87    Yes
# 1      2020.11.01          73     No
# 2    Jan 18, 2022          90      Y
# 3       2019/9/25          65      N
# 4        07/05/18          82    yes
# ...

# %%
#Columns Transformation using 
df['full_name'] = (
    df['full_name']
    .str.strip()
    .str.title()
    .str.replace(r"[\s-]+", " ", regex=True)
)

df['full_name'].to_list()

df
# Out:
#    emp_id      full_name     department          age    salary  \
# 0     101  Alice Johnson             IT           29  $5500.50
# 1     102  Micheal Smith             hr  thirty-five      4800
# 2     103      Sarah Lee          Mktng           26   4200.75
# 3     104      David Kim             IT           31       NaN
# 4     105            NaN  Customer Care           42      6100
# 5     106     John Brown      marketing           27     4,300
# 6     107    Emma Wilson        Finance           33      5800
# 7     108      Tom Davis            NaN           30      5000
# 8     109    Jane Miller             HR          NaN    4700.0
# 9     110   Chris Taylor      marketing           28      4400
#
#         join_date performance remote
# 0      12-04-2021          87    Yes
# 1      2020.11.01          73     No
# 2    Jan 18, 2022          90      Y
# 3       2019/9/25          65      N
# 4        07/05/18          82    yes
# 5      2021-10-14          75     no
# ...

# %%
#Replacing inconsistent values
df.replace({
    'hr': 'HR',
    'Mktng': 'Marketing',
    'marketing': 'Marketing',
    None: np.nan
}, inplace=True)

df['department']
# Out:
# 0               IT
# 1               HR
# 2        Marketing
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7              NaN
# 8               HR
# 9        Marketing
# Name: department, dtype: str

# %%
#Cleaning the Age Column
#def defines function
#isinstance(value) helps confirm the data type
#isdigit returns numbers that are in string format
#you must define the function "df['age'] = "

def clean_age(value):
    if value == "thirty-five":
        return 25
    elif isinstance(value, (int,float)):
        return (value)
    elif isinstance(value, str) and value.isdigit():
        return int(value)
    else:
        return np.nan
df['age'] = df['age'].apply(clean_age)
df['age']
# Out:
# 0    29.0
# 1    25.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8     NaN
# 9    28.0
# Name: age, dtype: float64

# %%
#Clean Salary

df['salary'] = (
    df['salary']
    .astype(str)
    .replace(r"[$,]", "", regex=True)
    .replace("NaN", np.nan)
    .astype(float)
)

df['salary']
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3        NaN
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: salary, dtype: float64

# %%
#Clean Perfomance
df['performance'] = (
    df['performance']
    .astype(str)
    .replace(r"%", " ", regex=True)
    .replace("None", np.nan)
    .astype(float)
)
df['performance']
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7     NaN
# 8    79.0
# 9    91.0
# Name: performance, dtype: float64

# %%
#Cleaning remote

df.replace({
    "yes": "Yes",
    "no": "No",
    "N": "No",
    "Y": "Yes",
    "Y": "Yes",
    "True": "Yes",
    None: np.nan,
}, inplace=True)

df
# Out:
#    emp_id      full_name     department   age   salary       join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50      12-04-2021
# 1     102  Micheal Smith             HR  25.0  4800.00      2020.11.01
# 2     103      Sarah Lee      Marketing  26.0  4200.75    Jan 18, 2022
# 3     104      David Kim             IT  31.0      NaN       2019/9/25
# 4     105            NaN  Customer Care  42.0  6100.00        07/05/18
# 5     106     John Brown      Marketing  27.0  4300.00      2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00      2019/12/01
# 7     108      Tom Davis            NaN  30.0  5000.00      2020-03-22
# 8     109    Jane Miller             HR   NaN  4700.00  May 10th, 2021
# 9     110   Chris Taylor      Marketing  28.0  4400.00      2022-02-05
#
#    performance remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# ...

# %%
#Cleaning inconsistent date value using pd.to_datetime(df['join_date'] 
#pd.to_datetime(df['join_date'] cannot handle complex date format, so we need to import "parser" from dateutil

#df['join_date'] = pd.to_datetime(df['join_date'], errors="coerce")
#df['join_date']

def date_parser(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NaT

df['join_date'] = df['join_date'].apply(date_parser)
df['join_date']
# Out:
# 0   2021-04-12
# 1   2020-01-11
# 2   2022-01-18
# 3   2019-09-25
# 4   2018-05-07
# 5   2021-10-14
# 6   2019-01-12
# 7   2020-03-22
# 8   2021-05-10
# 9   2022-05-02
# Name: join_date, dtype: datetime64[us]

# %%
#Changing number in string format using ".to_numeric"
df['emp_id'] = pd.to_numeric(df['emp_id'], errors='coerce')
df['emp_id']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: emp_id, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   emp_id       10 non-null     int64
#  1   full_name    9 non-null      str
#  2   department   9 non-null      str
#  3   age          9 non-null      float64
#  4   salary       9 non-null      float64
#  5   join_date    10 non-null     datetime64[us]
#  6   performance  9 non-null      float64
#  7   remote       9 non-null      str
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 772.0 bytes

# %%
#Handling missing values using ".fillna"
df['full_name'] = df['full_name'].fillna('Unknown')
df['full_name']
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: full_name, dtype: str

# %%
#Replacing the missing value in department with mode

df['department'] = df['department'].fillna(df['department'].mode()[0])
df['department']
# Out:
# 0               IT
# 1               HR
# 2        Marketing
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7        Marketing
# 8               HR
# 9        Marketing
# Name: department, dtype: str

# %%
#Replacing the missing value in age with the median
df['age'] = df['age'].fillna(df['age'].median())
df['age']
# Out:
# 0    29.0
# 1    25.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8    29.0
# 9    28.0
# Name: age, dtype: float64

# %%
#Replacing the missing value in salary with the median

df['salary'] = df['salary'].fillna(df['salary'].median())
df['salary']
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3    4800.00
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: salary, dtype: float64

# %%
#Replacing the missing value in performance with the median
df['performance'] = df['performance'].fillna(df['performance'].median())
df['performance']
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7    82.0
# 8    79.0
# 9    91.0
# Name: performance, dtype: float64

# %%
df['remote'] = df['remote'].fillna(df['remote'].mode()[0])
df['remote']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    Yes
# 9    Yes
# Name: remote, dtype: str

# %%
#Checking for missing values

df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   emp_id       10 non-null     int64
#  1   full_name    10 non-null     str
#  2   department   10 non-null     str
#  3   age          10 non-null     float64
#  4   salary       10 non-null     float64
#  5   join_date    10 non-null     datetime64[us]
#  6   performance  10 non-null     float64
#  7   remote       10 non-null     str
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 772.0 bytes
# emp_id         0
# full_name      0
# department     0
# age            0
# salary         0
# join_date      0
# performance    0
# remote         0
# dtype: int64

# %%
#Filtering using column names (field)

df['full_name']
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: full_name, dtype: str

# %%
#Filtering for the first 5 fields using .head
df.head()
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    performance remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes

# %%
#Filtering out some fields
df[['full_name', 'salary', 'performance']]
# Out:
#        full_name   salary  performance
# 0  Alice Johnson  5500.50         87.0
# 1  Micheal Smith  4800.00         73.0
# 2      Sarah Lee  4200.75         90.0
# 3      David Kim  4800.00         65.0
# 4        Unknown  6100.00         82.0
# 5     John Brown  4300.00         75.0
# 6    Emma Wilson  5800.00         88.0
# 7      Tom Davis  5000.00         82.0
# 8    Jane Miller  4700.00         79.0
# 9   Chris Taylor  4400.00         91.0

# %%
#Filtering by slicing using ".iloc"
df.iloc[0:3, 0:3]
# Out:
#    emp_id      full_name department
# 0     101  Alice Johnson         IT
# 1     102  Micheal Smith         HR
# 2     103      Sarah Lee  Marketing

# %%
#Filtering for conditions using ".loc"
df.loc[df['salary']>=5000]
# Out:
#    emp_id      full_name     department   age  salary  join_date  performance  \
# 0     101  Alice Johnson             IT  29.0  5500.5 2021-04-12         87.0
# 4     105        Unknown  Customer Care  42.0  6100.0 2018-05-07         82.0
# 6     107    Emma Wilson        Finance  33.0  5800.0 2019-01-12         88.0
# 7     108      Tom Davis      Marketing  30.0  5000.0 2020-03-22         82.0
#
#   remote
# 0    Yes
# 4    Yes
# 6    Yes
# 7    Yes

# %%
#Filtering by salary to display full_name, department, and salary

df.loc[df['salary'] >= 5000, ['full_name', 'department', 'salary']]
# Out:
#        full_name     department  salary
# 0  Alice Johnson             IT  5500.5
# 4        Unknown  Customer Care  6100.0
# 6    Emma Wilson        Finance  5800.0
# 7      Tom Davis      Marketing  5000.0

# %%
#Filtering by department for HR only

df.loc[df['department'] == 'HR']
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 1     102  Micheal Smith         HR  25.0  4800.0 2020-01-11         73.0
# 8     109    Jane Miller         HR  29.0  4700.0 2021-05-10         79.0
#
#   remote
# 1     No
# 8    Yes

# %%
#Filtering by department for HR only

df[df['department'] == 'HR']
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 1     102  Micheal Smith         HR  25.0  4800.0 2020-01-11         73.0
# 8     109    Jane Miller         HR  29.0  4700.0 2021-05-10         79.0
#
#   remote
# 1     No
# 8    Yes

# %%
#Filtering by department but excluding HR

df[df['department'] != 'HR']
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    performance remote
# 0         87.0    Yes
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 9         91.0    Yes

# %%
df[df['age'] > 30]
# Out:
#    emp_id    full_name     department   age  salary  join_date  performance  \
# 3     104    David Kim             IT  31.0  4800.0 2019-09-25         65.0
# 4     105      Unknown  Customer Care  42.0  6100.0 2018-05-07         82.0
# 6     107  Emma Wilson        Finance  33.0  5800.0 2019-01-12         88.0
#
#   remote
# 3     No
# 4    Yes
# 6    Yes

# %%
#Filtering with multiple conditions
#Remote workers whose salary is greater than 5000
df[
    (df['salary'] > 5000) & (df['remote'] == 'Yes')
]
# Out:
#    emp_id      full_name     department   age  salary  join_date  performance  \
# 0     101  Alice Johnson             IT  29.0  5500.5 2021-04-12         87.0
# 4     105        Unknown  Customer Care  42.0  6100.0 2018-05-07         82.0
# 6     107    Emma Wilson        Finance  33.0  5800.0 2019-01-12         88.0
#
#   remote
# 0    Yes
# 4    Yes
# 6    Yes

# %%
#Where the employee is a remote worker or performance less than 50
df[
    (df['performance'] < 50) | (df['remote'] == 'Yes')
]
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    performance remote
# 0         87.0    Yes
# 2         90.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
#Checking for membership using 'isin'

df[df['department'].isin(['IT', 'Finance'])]
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 3     104      David Kim         IT  31.0  4800.0 2019-09-25         65.0
# 6     107    Emma Wilson    Finance  33.0  5800.0 2019-01-12         88.0
#
#   remote
# 0    Yes
# 3     No
# 6    Yes

# %%
#Filtering using 'str.startswith'
df[df['department'].str.startswith('M')]
# Out:
#    emp_id     full_name department   age   salary  join_date  performance  \
# 2     103     Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 5     106    John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 7     108     Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 9     110  Chris Taylor  Marketing  28.0  4400.00 2022-05-02         91.0
#
#   remote
# 2    Yes
# 5     No
# 7    Yes
# 9    Yes

# %%
#Filtering for a name using '.str.contains'
#case=False ignores case


df[df['full_name'].str.contains('john', case=False)]
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 5     106     John Brown  Marketing  27.0  4300.0 2021-10-14         75.0
#
#   remote
# 0    Yes
# 5     No

# %%
#Sorting in Pandas using '.sort_values' 
#Ascending

df.sort_values('salary')
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    performance remote
# 2         90.0    Yes
# 5         75.0     No
# 9         91.0    Yes
# 8         79.0    Yes
# 3         65.0     No
# 1         73.0     No
# 7         82.0    Yes
# 0         87.0    Yes
# 6         88.0    Yes
# ...

# %%
#Sorting Descending

df.sort_values('salary', ascending=False)
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
#
#    performance remote
# 4         82.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 7         82.0    Yes
# 1         73.0     No
# 3         65.0     No
# 8         79.0    Yes
# 9         91.0    Yes
# 5         75.0     No
# ...

# %%
#Sorting Descending
#Top 5 using '.head()'

df.sort_values('salary', ascending=False).head()
# Out:
#    emp_id      full_name     department   age  salary  join_date  performance  \
# 4     105        Unknown  Customer Care  42.0  6100.0 2018-05-07         82.0
# 6     107    Emma Wilson        Finance  33.0  5800.0 2019-01-12         88.0
# 0     101  Alice Johnson             IT  29.0  5500.5 2021-04-12         87.0
# 7     108      Tom Davis      Marketing  30.0  5000.0 2020-03-22         82.0
# 1     102  Micheal Smith             HR  25.0  4800.0 2020-01-11         73.0
#
#   remote
# 4    Yes
# 6    Yes
# 0    Yes
# 7    Yes
# 1     No

# %%
#Sorting Using alphabet

df.sort_values('department')
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    performance remote
# 4         82.0    Yes
# 6         88.0    Yes
# 1         73.0     No
# 8         79.0    Yes
# 0         87.0    Yes
# 3         65.0     No
# 2         90.0    Yes
# 5         75.0     No
# 7         82.0    Yes
# ...

# %%
#Sorting using multiple fields

df.sort_values(['department', 'performance'], ascending=[False, True])
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    performance remote
# 5         75.0     No
# 7         82.0    Yes
# 2         90.0    Yes
# 9         91.0    Yes
# 3         65.0     No
# 0         87.0    Yes
# 1         73.0     No
# 8         79.0    Yes
# 6         88.0    Yes
# ...

# %%
#Counting occurence in a field using 'value_counts()'

df['department'].value_counts()
# Out:
# department
# Marketing        4
# IT               2
# HR               2
# Customer Care    1
# Finance          1
# Name: count, dtype: int64

# %%
#Counting occurence in a field using 'value_counts()'

df['remote'].value_counts()
# Out:
# remote
# Yes    7
# No     3
# Name: count, dtype: int64

# %%
#Counting occurence in a field using 'value_counts()'
#Converting it to percentage using 'normalize=True'

df['department'].value_counts(normalize=True)
# Out:
# department
# Marketing        0.4
# IT               0.2
# HR               0.2
# Customer Care    0.1
# Finance          0.1
# Name: proportion, dtype: float64

# %%
#14th May
#Merging two data set

data1 = {
    "department": ["IT", "HR", "Finance", "Marketing", "R&D", "Operations", "Sales", "Logistics", "Procurement", "Customer Service"],
    "manager": [
        "Tom Hanks", "Susan Lee", "Robert Miles", 
        "Mark Chan", "Sarah Connor", "James Nwosu", "Adaeze Obi", 
        "Daniel Smith", "Amina Yusuf", "Grace Ojo"
    ],
    "department_budget": [200000, 150000, 250000, 180000, 300000, 220000, 210000, 195000, 230000, 170000],
    "office_location": [
        "Lagos", "Abuja", "Port Harcourt", "Ibadan", "Enugu", "Kano",
        "Lagos", "Calabar", "Abuja", "Kano"
    ]
}
#Gives the data structure
df1 = pd.DataFrame(data1)

#Convert to csv
df1.to_csv('data/department_data.csv', index=False)
df1 = pd.read_csv('data/department_data.csv')

df1
# Out:
#          department       manager  department_budget office_location
# 0                IT     Tom Hanks             200000           Lagos
# 1                HR     Susan Lee             150000           Abuja
# 2           Finance  Robert Miles             250000   Port Harcourt
# 3         Marketing     Mark Chan             180000          Ibadan
# 4               R&D  Sarah Connor             300000           Enugu
# 5        Operations   James Nwosu             220000            Kano
# 6             Sales    Adaeze Obi             210000           Lagos
# 7         Logistics  Daniel Smith             195000         Calabar
# 8       Procurement   Amina Yusuf             230000           Abuja
# 9  Customer Service     Grace Ojo             170000            Kano

# %%
#Merging

merge_df = pd.merge(df, df1, how='inner')
merge_df
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  25.0  4800.00 2020-01-11         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 3     104      David Kim         IT  31.0  4800.00 2019-09-25         65.0
# 4     106     John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 5     107    Emma Wilson    Finance  33.0  5800.00 2019-01-12         88.0
# 6     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 7     109    Jane Miller         HR  29.0  4700.00 2021-05-10         79.0
# 8     110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02         91.0
#
#   remote       manager  department_budget office_location
# 0    Yes     Tom Hanks             200000           Lagos
# 1     No     Susan Lee             150000           Abuja
# ...

# %%
#Leftmerge

left_merge = pd.merge(df, df1, how='left')
left_merge
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  25.0  4800.00 2020-01-11
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8     109    Jane Miller             HR  29.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    performance remote       manager  department_budget office_location
# 0         87.0    Yes     Tom Hanks           200000.0           Lagos
# 1         73.0     No     Susan Lee           150000.0           Abuja
# ...

# %%
#Rightmerge

right_merge = pd.merge(df, df1, how='right')
right_merge
# Out:
#     emp_id      full_name        department   age   salary  join_date  \
# 0    101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 1    104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 2    102.0  Micheal Smith                HR  25.0  4800.00 2020-01-11
# 3    109.0    Jane Miller                HR  29.0  4700.00 2021-05-10
# 4    107.0    Emma Wilson           Finance  33.0  5800.00 2019-01-12
# 5    103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 6    106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 7    108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# 8    110.0   Chris Taylor         Marketing  28.0  4400.00 2022-05-02
# 9      NaN            NaN               R&D   NaN      NaN        NaT
# 10     NaN            NaN        Operations   NaN      NaN        NaT
# 11     NaN            NaN             Sales   NaN      NaN        NaT
# ...

# %%
#Fullmerge

full_merge = pd.merge(df, df1, how='outer')
full_merge
# Out:
#     emp_id      full_name        department   age   salary  join_date  \
# 0    105.0        Unknown     Customer Care  42.0  6100.00 2018-05-07
# 1      NaN            NaN  Customer Service   NaN      NaN        NaT
# 2    107.0    Emma Wilson           Finance  33.0  5800.00 2019-01-12
# 3    102.0  Micheal Smith                HR  25.0  4800.00 2020-01-11
# 4    109.0    Jane Miller                HR  29.0  4700.00 2021-05-10
# 5    101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 6    104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 7      NaN            NaN         Logistics   NaN      NaN        NaT
# 8    103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 9    106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 10   108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# 11   110.0   Chris Taylor         Marketing  28.0  4400.00 2022-05-02
# ...

# %%
#Analysing Data using 'df.groupby()'
#FINDING AVERAGE OF SALARY USING DEPARTMENT
#.sort_values(ascending=False) SORTING BY SALARY


merge_df.groupby('department')['salary'].mean().sort_values(ascending=False)
# Out:
# department
# Finance      5800.0000
# IT           5150.2500
# HR           4750.0000
# Marketing    4475.1875
# Name: salary, dtype: float64

# %%
#FINDING AVERAGE OF SALARY AND PERFORMANCE USING DEPARTMENT
#.sort_values(by=['performance', 'salary'], ascending=[False, False]) SORTING MULTIPLE
#.sort_values(by=['salary'], ascending=[False]) SORTING BY SALARY

merge_df.groupby('department')[['performance', 'salary']].mean().sort_values(by=['performance', 'salary'], ascending=[False, False])
# Out:
#             performance     salary
# department
# Finance            88.0  5800.0000
# Marketing          84.5  4475.1875
# IT                 76.0  5150.2500
# HR                 76.0  4750.0000

# %%
#18th May
#Writing multiple aggregations at once using '.agg'

merge_df.groupby('department').agg(
    avg_salary=('salary', 'mean'),
    total_salary=('salary', 'sum'),
    total_employee=('salary', 'count'),
    min_salary=('salary', 'min'),
    max_salary=('salary', 'max'),
)
# Out:
#             avg_salary  total_salary  total_employee  min_salary  max_salary
# department
# Finance      5800.0000       5800.00               1     5800.00      5800.0
# HR           4750.0000       9500.00               2     4700.00      4800.0
# IT           5150.2500      10300.50               2     4800.00      5500.5
# Marketing    4475.1875      17900.75               4     4200.75      5000.0

# %%
#Writing multiple aggregations at once using '.agg' and multiple fields

merge_df.groupby('department').agg(
    avg_salary=('salary', 'mean'),
    avg_performance=('performance', 'mean'),
    total_employee=('emp_id', 'count')
).reset_index()
# Out:
#   department  avg_salary  avg_performance  total_employee
# 0    Finance   5800.0000             88.0               1
# 1         HR   4750.0000             76.0               2
# 2         IT   5150.2500             76.0               2
# 3  Marketing   4475.1875             84.5               4

# %%
#Applying index for proper structure using '.reset_index()'
merge_df.groupby('department')['salary'].mean().reset_index()
# Out:
#   department     salary
# 0    Finance  5800.0000
# 1         HR  4750.0000
# 2         IT  5150.2500
# 3  Marketing  4475.1875

# %%
#Lambda - used in writing short functions for manipulation of filtering

merge_df.groupby('department')['salary'].apply(lambda x: x.std())
# Out:
# department
# Finance             NaN
# HR            70.710678
# IT           495.328300
# Marketing    359.206497
# Name: salary, dtype: float64

# %%
#Finding Range using Lambda
merge_df.groupby('department')['salary'].apply(lambda x: x.max() - x.min())
# Out:
# department
# Finance        0.00
# HR           100.00
# IT           700.50
# Marketing    799.25
# Name: salary, dtype: float64

# %%
#Filtering using lambda
merge_df.groupby('department').filter(lambda x: x['salary'].mean() >= 5000)
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 3     104      David Kim         IT  31.0  4800.0 2019-09-25         65.0
# 5     107    Emma Wilson    Finance  33.0  5800.0 2019-01-12         88.0
#
#   remote       manager  department_budget office_location
# 0    Yes     Tom Hanks             200000           Lagos
# 3     No     Tom Hanks             200000           Lagos
# 5    Yes  Robert Miles             250000   Port Harcourt

# %%
#Adding a new column using transform

merge_df['department_avg_salary'] = merge_df.groupby('department')['salary'].transform('mean')
merge_df
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  25.0  4800.00 2020-01-11         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 3     104      David Kim         IT  31.0  4800.00 2019-09-25         65.0
# 4     106     John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 5     107    Emma Wilson    Finance  33.0  5800.00 2019-01-12         88.0
# 6     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 7     109    Jane Miller         HR  29.0  4700.00 2021-05-10         79.0
# 8     110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02         91.0
#
#   remote       manager  department_budget office_location  \
# 0    Yes     Tom Hanks             200000           Lagos
# 1     No     Susan Lee             150000           Abuja
# ...

# %%
#Detecting outliers using the ".quantile()"
Q1 = merge_df['salary'].quantile(0.25)
Q3 = merge_df['salary'].quantile(0.75)

IQR = Q3 - Q1

IQR
# Out:
# np.float64(600.0)

# %%
#Finding the Lower and upper bound
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

outliers = (merge_df['salary'] < lower_bound) | (merge_df['salary'] > upper_bound)

print('Outliers:', outliers.sum())

lower_bound
upper_bound
# Out:
# Outliers: 0
# np.float64(5900.0)

# %%
#Excluding Outliers from dataframe using ""

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

new_df = merge_df[
    (merge_df['salary'] > lower_bound) & (merge_df['salary'] < upper_bound)
]

new_df
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  25.0  4800.00 2020-01-11         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 3     104      David Kim         IT  31.0  4800.00 2019-09-25         65.0
# 4     106     John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 5     107    Emma Wilson    Finance  33.0  5800.00 2019-01-12         88.0
# 6     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 7     109    Jane Miller         HR  29.0  4700.00 2021-05-10         79.0
# 8     110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02         91.0
#
#   remote       manager  department_budget office_location  \
# 0    Yes     Tom Hanks             200000           Lagos
# 1     No     Susan Lee             150000           Abuja
# ...

# %%
#VISUALIZATION USING MATPLOTLIB 
#Average salary by department
#declare "df_sorted" to sort in descending order


df_sorted = merge_df.sort_values('department_avg_salary', ascending=False)
plt.bar(df_sorted['department'], df_sorted['department_avg_salary'])
plt.title('AVERAGE SALARY BY DEPARTMENT')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.grid(axis='y', linestyle='-', alpha=1)

# %%
#Checking proportionsl distribution using ".pie"
#remote_status assigns 'remote' to the highest and 'onsite' to lowest 
#'%1.1f%%' displays "%" and '1.1f' gives 1 decimal place

remote_status = ['Remote', 'Onsite']
plt.pie(merge_df['remote'].value_counts(), labels=remote_status, autopct='%1.1f%%')
plt.title('Distribution Proportion of Remote Employee')
plt.show()

# %%
#Stacked Chart
#Visualizing department average salary and employee salary on stacked chart

plt.bar(merge_df['department'], merge_df['department_budget'], color='green', label='Budget')
plt.bar(merge_df['department'], merge_df['department_avg_salary'], color='blue', label='Average Salary')
plt.title('Average Salary and Department Budget By Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()

# %%
#Visualizing performance trends using Line Trend .plot

plt.plot(merge_df['full_name'], merge_df['performance'], color='blue', marker='o')
plt.title('Performance Trends by Employee')
plt.xlabel('Employee')
plt.ylabel('Performance')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='-', alpha=1)

# %%
#Using Scatter Chart in visualising correlation
#Relationship Between Performance and Salary

plt.scatter(merge_df['salary'], merge_df['performance'], color='orange')
plt.title('Relationship Between Performance and Salary')
plt.xlabel('Salary')
plt.ylabel('Performance')
plt.grid(linestyle='-', alpha=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Finding correlation between the numerical fields
#annot=True shows the value
#num_cols assigns a variable to the fields
#corr = merge_df[num_cols].corr() calculates the correlation

num_cols = ['age', 'salary', 'performance', 'department_budget', 'department_avg_salary']
corr = merge_df[num_cols].corr()

sns.heatmap(corr, annot=True, cmap="vlag", fmt='.2f')

plt.title('Correlation')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Histogram distribution of salary by employee
#bins=6 adjusts the number of bins from the default 10
#edgecolor='white' changes the colours to make it readable

plt.hist(merge_df['salary'], color='blue', bins=6, edgecolor='white')
plt.title('Distribution of Salary by Employee')
plt.xlabel('Salary')
plt.ylabel('Number of Employee')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Boxplot used in summarizing dataset vissually by breaking them into quartiles. used only for numerical values.

sns.boxplot(merge_df['salary']) #It's only on Seaborn library
plt.title('Boxplot Summary of Salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Creating multiple Boxplot summaries using for loop

num_cols = ['age', 'salary', 'performance', 'department_budget', 'department_avg_salary']
plt.figure(figsize=(12, 6)) #resize the frame from the default 6.4 by 4.6 inches
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(merge_df[col])
    plt.title(col)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plotly pie chat. you must declare a variable for the chart inorder to call the visuals out

dept_count = merge_df['department'].value_counts()
fig = px.pie(
    values=dept_count.values,
    names=dept_count.index,
    title='Distribution Values by Department'
)
fig.show()

# %%
#Bar chart on Plotly
#.update_layout() changes the axis name
#orientation='v' changes the chart orientation to column

avg_salary = merge_df.groupby('department')['salary'].mean().sort_values()
fig1 = px.bar(
    x=avg_salary.values,
    y=avg_salary.index,
    title='Average Salary by Department'

)
fig1.update_layout(xaxis_title='Salary', yaxis_title='Department')
fig1.show()

# %%
#Plotly Histogram
#Distribution of Employee Performance
fig2 = px.histogram(
    merge_df,
    x='performance',
    nbins=6,
    title='Distribution of Employee Performance'
)
fig2.update_traces(
    marker_line_color='red',
    marker_line_width=1
)
fig2.show()

# %%
#Using Boxplot on Plotly
fig3 = px.box(
    merge_df,
    y='salary',
    title='Boxplot Summary for Salary',
)

fig3.show()

# %%
#Converting the Clean Data to csv
merge_df.to_csv('data/employee_clean_data.csv', index=False)
